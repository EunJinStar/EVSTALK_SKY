# %%
# !python detect.py --source "./carnumber/20221209_084133.mp4" --weights ./runs/detect/carnum_mk2/weights/best.pt
# Out:
# detect: weights=['./runs/detect/carnum_mk2/weights/best.pt'], source=./carnumber/20221209_084133.mp4, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# ...
